# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data=pd.read_csv(r"D:\Downloads\Furniture.csv")
data.head(5)
# Out:
#         price        cost  sales  profit_margin  inventory  \
# 0  218.543053  181.610932     40      16.899243        105
# 1  477.821438  385.033827      7      19.418888        192
# 2  379.397274  276.736765     32      27.058842         59
# 3  319.396318  281.841334     48      11.758114         45
# 4  120.208388   69.743681     19      41.981019         35
#
#    discount_percentage  delivery_days category material  color  location  \
# 0            27.796433              9      Bed  Plastic    Red     Rural
# 1            26.943715              6    Chair    Glass   Blue     Rural
# 2            21.948130              2    Table    Metal  Black  Suburban
# 3            11.009944              2    Table    Glass  Green     Rural
# 4             3.183763              9    Chair    Glass  Brown     Rural
#
#    season store_type   brand       revenue
# 0  Spring     Online  BrandA   3949.165238
# 1  Summer     Online  BrandD  -3521.002258
# ...

# %%
data.describe()
# Out:
#              price         cost        sales  profit_margin    inventory  \
# count  2500.000000  2500.000000  2500.000000    2500.000000  2500.000000
# mean    274.495219   191.930107    24.924000      30.208571    97.715600
# std     130.898452    98.590751    14.050067      11.536804    57.616228
# min      50.704297    26.505895     1.000000      10.017692     0.000000
# 25%     159.104890   106.399135    13.000000      20.230697    50.000000
# 50%     277.641809   189.336329    25.000000      30.297911    94.000000
# 75%     387.378046   263.188280    37.000000      40.134205   147.000000
# max     499.872953   447.022911    49.000000      49.999535   199.000000
#
#        discount_percentage  delivery_days       revenue
# count          2500.000000     2500.00000   2500.000000
# mean             14.947616        4.89400   5926.853657
# std               8.621547        2.55902   6902.737604
# min               0.005556        1.00000 -14214.565505
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   price                2500 non-null   float64
#  1   cost                 2500 non-null   float64
#  2   sales                2500 non-null   int64
#  3   profit_margin        2500 non-null   float64
#  4   inventory            2500 non-null   int64
#  5   discount_percentage  2500 non-null   float64
#  6   delivery_days        2500 non-null   int64
#  7   category             2500 non-null   object
#  8   material             2500 non-null   object
#  9   color                2500 non-null   object
#  10  location             2500 non-null   object
#  11  season               2500 non-null   object
#  12  store_type           2500 non-null   object
#  13  brand                2500 non-null   object
#  14  revenue              2500 non-null   float64
# ...

# %%
d=data.drop("store_type",axis=1)
d
# Out:
#            price        cost  sales  profit_margin  inventory  \
# 0     218.543053  181.610932     40      16.899243        105
# 1     477.821438  385.033827      7      19.418888        192
# 2     379.397274  276.736765     32      27.058842         59
# 3     319.396318  281.841334     48      11.758114         45
# 4     120.208388   69.743681     19      41.981019         35
# ...          ...         ...    ...            ...        ...
# 2495  271.546466  233.247261      8      14.104107        102
# 2496  309.775563  169.680310     24      45.224760          9
# 2497  439.509716  277.390903     48      36.886286        127
# 2498  491.332705  405.987306     38      17.370185          6
# 2499  233.412894  172.474611      6      26.107505         55
#
#       discount_percentage  delivery_days category material  color  location  \
# 0               27.796433              9      Bed  Plastic    Red     Rural
# ...

# %%
sns.countplot(y="material",data=d,color="red",label="material count")
# Out:
# <Axes: xlabel='count', ylabel='material'>

# %%
sns.barplot(x="category",y="revenue",color="red",data=d,label="cr")
# Out:
# <Axes: xlabel='category', ylabel='revenue'>

# %%
plt.figure(figsize=(15,7))
plt.bar(d["category"],d["revenue"],color="black",label="revenue")
plt.ylabel("revenue")
plt.xlabel("category")
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   price                2500 non-null   float64
#  1   cost                 2500 non-null   float64
#  2   sales                2500 non-null   int64
#  3   profit_margin        2500 non-null   float64
#  4   inventory            2500 non-null   int64
#  5   discount_percentage  2500 non-null   float64
#  6   delivery_days        2500 non-null   int64
#  7   category             2500 non-null   object
#  8   material             2500 non-null   object
#  9   color                2500 non-null   object
#  10  location             2500 non-null   object
#  11  season               2500 non-null   object
#  12  brand                2500 non-null   object
#  13  revenue              2500 non-null   float64
# dtypes: float64(5), int64(3), object(6)
# memory usage: 273.6+ KB

# %%
ob1=LabelEncoder()
d["category"]=ob1.fit_transform(d["category"])
ob2=LabelEncoder()
d["material"]=ob2.fit_transform(d["material"])
ob3=LabelEncoder()
d["color"]=ob3.fit_transform(d["color"])
ob4=LabelEncoder()
d["location"]=ob4.fit_transform(d["location"])
ob5=LabelEncoder()
d["season"]=ob5.fit_transform(d["season"])
ob6=LabelEncoder()
d["brand"]=ob6.fit_transform(d["brand"])

# %%
d
# Out:
#            price        cost  sales  profit_margin  inventory  \
# 0     218.543053  181.610932     40      16.899243        105
# 1     477.821438  385.033827      7      19.418888        192
# 2     379.397274  276.736765     32      27.058842         59
# 3     319.396318  281.841334     48      11.758114         45
# 4     120.208388   69.743681     19      41.981019         35
# ...          ...         ...    ...            ...        ...
# 2495  271.546466  233.247261      8      14.104107        102
# 2496  309.775563  169.680310     24      45.224760          9
# 2497  439.509716  277.390903     48      36.886286        127
# 2498  491.332705  405.987306     38      17.370185          6
# 2499  233.412894  172.474611      6      26.107505         55
#
#       discount_percentage  delivery_days  category  material  color  location  \
# 0               27.796433              9         0         3      4         0
# ...

# %%
x=d.drop(["price"],axis=1)
y=d["price"]

# %%
# from sklearn.feature_selection import SelectKBest
# best_feature=SelectKBest()
# fit=best_feature.fit(x,y)
# fit

# %%
# dfscore=pd.DataFrame(fit.scores_,columns=['score'])
# dfcol=pd.DataFrame(x.columns,columns=['feature'])
# fs=pd.concat([dfcol,dfscore],axis=1)
# fs

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
xtest
# Out:
#             cost  sales  profit_margin  inventory  discount_percentage  \
# 1447  316.510905     24      25.902022        191            27.919875
# 1114  204.970614     18      35.304371        191            29.321072
# 1064  163.743346     35      31.662743         47            29.295059
# 2287  171.653317     10      13.788040         92            18.041527
# 1537  291.450942     25      18.247276        176            27.930578
# ...          ...    ...            ...        ...                  ...
# 427   401.797935     32      10.605664        182            26.613195
# 105   114.249028     44      29.554834         80             2.359862
# 2044  288.516181      9      33.987487         92             7.069321
# 121   388.313782     32      14.325114         31             3.801382
# 821    27.426886     35      47.341467         69            16.810559
#
#       delivery_days  category  material  color  location  season  brand  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
xtrain=scaler.fit_transform(xtrain)

# %%
xtest=scaler.transform(xtest)

# %% [markdown]
# **linear regression**

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()
model1.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
print(model1.score(xtest,ytest))
print(model1.score(xtrain,ytrain))
# Out:
# 0.9722759110631494
# 0.9728604807579079

# %%
y_pred1=model1.predict(xtest)
y_pred1
# Out:
# array([431.36876377, 311.88640596, 244.81307092, 184.44291781,
#        371.45981795, 114.29435605, 269.4696741 , 369.91104088,
#        108.00720424, 147.14476299, 445.53813548, 240.0058328 ,
#        368.83861017, 271.64420558, 121.63582096, 194.26713489,
#        294.76217492,  32.48260537, 275.36265255, 435.9013898 ,
#        162.48298544, 389.04265728,  84.34568645, 210.26604299,
#        383.04469864, 471.33616377,  63.59514728, 114.70963956,
#        215.14282017, 347.7547253 , 492.2359866 , 187.24786787,
#        290.97901188, 262.53314424, 520.57825903, 331.89236875,
#        329.05341457, 369.28995783, 321.59918477,  88.50555821,
#        455.83930443,  45.67252105, 178.86102519, 225.63420935,
#         83.65338089, 132.50638223, 440.38725174, 495.13310117,
#        154.23853275, 350.49181269, 392.16091187, 420.57658028,
#        430.41853632, 306.18234893,  90.94342711, 359.81072879,
#        210.10259825, 366.08959063, 327.57680865, 338.17699961,
# ...

# %%
model1.predict([[181.610932,40,16.899243,105,27.796433,9,0,3,4,0,1,0,3949.165238]])
# Out:
# array([35715.55027452])

# %% [markdown]
# **Decisiontree**

# %%
from sklearn.tree import DecisionTreeRegressor
model2=DecisionTreeRegressor()
model2.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
print(model2.score(xtest,ytest))
print(model2.score(xtrain,ytrain))
# Out:
# 0.994633187399748
# 1.0

# %%
y_pred2=model2.predict(xtest)
y_pred2
# Out:
# array([410.03193591, 299.84036522, 258.20590355, 193.59521296,
#        341.36362137, 134.33537484, 263.37822309, 363.20927812,
#         87.25940057, 176.30744698, 484.01449426, 234.20030284,
#        409.23283054, 280.07395799, 120.26866881, 186.77588056,
#        297.28799705,  75.68908524, 272.09596115, 465.97828792,
#        143.82973146, 392.67978427,  73.14161607, 231.34108044,
#        392.67978427, 445.54050513,  57.46452302,  84.67622561,
#        188.28048422, 386.36192216, 471.82462992, 214.06717769,
#        290.12114603, 253.54322803, 477.77321612, 338.8871752 ,
#        355.84127721, 371.33911946, 326.03683817,  81.21258539,
#        495.7273139 ,  67.7045933 , 182.06997044, 223.74618701,
#        107.41113626, 161.92142266, 457.85947329, 471.82462992,
#        167.76755768, 348.71203743, 392.80918612, 399.38583233,
#        419.73660397, 299.38010113,  83.32009328, 336.50135698,
#        203.47985797, 357.90486193, 313.80342441, 350.88944897,
# ...

# %%
model2.predict([[181.610932,40,16.899243,105,27.796433,9,0,3,4,0,1,0,3949.165238]])
# Out:
# array([497.94688229])

# %% [markdown]
# **kneighbors**

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model3=KNeighborsRegressor(n_neighbors=5)
model3.fit(xtrain,ytrain)
# Out:
# KNeighborsRegressor()

# %%
print(model3.score(xtest,ytest))
print(model3.score(xtrain,ytrain))
# Out:
# 0.7527397455849496
# 0.8462403362208659

# %%
y_pred3=model3.predict(xtest)
y_pred3
# Out:
# array([330.07285719, 269.44979792, 225.76353451, 249.5223836 ,
#        362.43321261, 223.43566895, 293.44371732, 312.37216263,
#        193.22020395, 261.50280863, 389.08800374, 213.97886625,
#        328.08196634, 255.14000416, 171.47581298, 237.81713789,
#        390.60740023, 161.66115075, 200.48186378, 316.08556581,
#        194.27681342, 375.25736579, 166.83533753, 273.29014172,
#        299.35069514, 399.0518435 ,  86.45317874, 163.267223  ,
#        197.68470242, 254.07873163, 408.54464437, 231.80642583,
#        277.93579432, 295.80963942, 396.652382  , 313.22552292,
#        299.01508963, 388.9499941 , 303.71703156, 139.18767929,
#        401.01134005,  96.72421879, 152.12050851, 350.14141976,
#        113.58245975, 190.19093966, 320.15341064, 399.33850356,
#        190.74859403, 380.91156446, 360.71166212, 424.29396935,
#        404.34499707, 296.10445458, 162.22138623, 358.41501138,
#        159.28348134, 302.09696698, 276.36605411, 290.6867178 ,
# ...

# %%
model3.predict([[181.610932,40,16.899243,105,27.796433,9,0,3,4,0,1,0,3949.165238]])
# Out:
# array([367.46815595])

# %% [markdown]
# **randomforest**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model4=RandomForestRegressor(n_estimators=100)
model4.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor()

# %%
print(model4.score(xtest,ytest))
print(model4.score(xtrain,ytrain))
# Out:
# 0.9988299898456177
# 0.9998287878556177

# %%
ypred=model4.predict(xtest)
ypred
# Out:
# array([425.59365118, 315.39071472, 240.94935216, 199.74084961,
#        358.64182747, 136.66648969, 273.57119124, 358.56615294,
#         86.19639059, 177.60903072, 482.67813327, 249.59214113,
#        408.63163603, 276.82376153, 129.25688442, 187.42907716,
#        294.32929056,  83.10540211, 266.95254579, 464.06003605,
#        144.87817765, 381.50600169,  78.98306359, 226.70843545,
#        376.08256522, 434.44971735,  58.40845481,  82.02256906,
#        196.62273393, 380.10686992, 478.11941523, 211.25930938,
#        292.80470023, 254.70255696, 481.56161587, 342.593389  ,
#        329.22969029, 372.89355894, 325.57251983,  81.79572619,
#        477.51237191,  68.88953985, 174.08584336, 226.94540974,
#        106.53663349, 155.10011554, 454.23462576, 477.66631076,
#        163.44871584, 339.90270928, 405.69288419, 412.46126058,
#        415.92179218, 302.94544487,  86.38988657, 337.36267826,
#        202.17886819, 357.85956842, 319.1806683 , 353.97230785,
# ...

# %%
model4.predict([[181.610932,40,16.899243,105,27.796433,9,0,3,4,0,1,0,3949.165238]])
# Out:
# array([488.9065446])

# %% [markdown]
# **adaboost**

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
model5=AdaBoostRegressor(n_estimators=100,learning_rate=0.3,random_state=1)
model5.fit(xtrain,ytrain)
# Out:
# AdaBoostRegressor(learning_rate=0.3, n_estimators=100, random_state=1)

# %%
print(model5.score(xtest,ytest))
print(model5.score(xtrain,ytrain))
# Out:
# 0.9683581823045374
# 0.9740440348599829

# %%
ypred=model5.predict(xtest)
ypred
# Out:
# array([420.38194491, 324.93777032, 235.07845279, 227.00718388,
#        389.31156681, 166.47716527, 291.21565144, 396.7826035 ,
#         86.8714935 , 208.58792193, 452.13778033, 240.93447869,
#        385.52093806, 274.07102383, 148.87025481, 181.96660024,
#        330.18826793, 106.16698087, 252.34178703, 440.81252276,
#        127.41096372, 396.3695508 ,  86.8714935 , 266.96004074,
#        391.31128339, 460.92746622,  86.8714935 ,  86.8714935 ,
#        170.00140748, 358.49433686, 460.92746622, 237.33230491,
#        314.29107532, 265.10116812, 464.76071572, 354.09824132,
#        330.18826793, 380.15582798, 327.20807907,  86.8714935 ,
#        430.82901811,  86.8714935 , 172.75825103, 223.83051052,
#        127.06134737, 194.52205501, 417.00265873, 462.72241534,
#        184.18154496, 387.05315516, 421.79102696, 416.9951402 ,
#        430.82901811, 302.06913774,  95.41261952, 365.38600326,
#        205.26583111, 386.49095557, 330.42582015, 361.80567182,
# ...

# %%
model5.predict([[181.610932,40,16.899243,105,27.796433,9,0,3,4,0,1,0,3949.165238]])
# Out:
# array([474.99512393])

# %% [markdown]
# **GradientBoost**

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
model6=GradientBoostingRegressor(n_estimators=100,random_state=24)
model6.fit(xtrain,ytrain)
# Out:
# GradientBoostingRegressor(random_state=24)

# %%
print(model6.score(xtest,ytest))
print(model6.score(xtrain,ytrain))
# Out:
# 0.9981688194473542
# 0.9990718620599288

# %%
ypred=model6.predict(xtest)
ypred
# Out:
# array([429.08015957, 311.46574001, 234.83079839, 193.66890101,
#        352.61736855, 137.12720782, 269.49059051, 358.44898119,
#         85.86616501, 171.57533   , 480.423953  , 250.09140405,
#        409.29281822, 270.44118435, 126.73086447, 186.52974407,
#        294.38540475,  81.59313647, 271.89547023, 460.57826319,
#        137.20563824, 379.31302023,  79.55095603, 230.25191386,
#        372.62211799, 441.16207095,  57.96087707,  83.63893326,
#        200.72628983, 378.01126055, 474.97338814, 202.74290382,
#        304.11847741, 253.01353045, 480.93763644, 345.85152207,
#        321.7049988 , 370.19854122, 318.48870407,  80.77496471,
#        470.37712617,  69.64487872, 168.17824913, 223.28355851,
#        111.25115648, 155.8127003 , 451.56445904, 473.20741992,
#        157.90977294, 338.6453372 , 408.92665635, 415.95827558,
#        423.62301303, 299.2998196 ,  91.50765531, 340.08136645,
#        202.92977036, 361.83770579, 312.86972903, 369.06105675,
# ...

# %%
model6.predict([[181.610932,40,16.899243,105,27.796433,9,0,3,4,0,1,0,3949.165238]])
# Out:
# array([588.76980552])

# %% [markdown]
# **xgboost**

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBRegressor

# %%
mmodel7=XGBRegressor(n_estimators=100,random_state=24)
mmodel7.fit(xtrain,ytrain)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=24, ...)

# %%
print(mmodel7.score(xtest,ytest))
print(mmodel7.score(xtrain,ytrain))
# Out:
# 0.9984675719260427
# 0.9999837513015506

# %%
ypred=mmodel7.predict(xtest)
ypred
# Out:
# array([418.5748  , 313.87375 , 236.32332 , 193.65358 , 359.22513 ,
#        136.1996  , 271.62335 , 360.55093 ,  89.10661 , 173.5421  ,
#        486.2161  , 244.67053 , 408.5851  , 275.81708 , 132.47307 ,
#        181.11359 , 294.6455  ,  75.86363 , 274.72656 , 479.8853  ,
#        145.97995 , 386.0774  ,  76.54671 , 224.81355 , 387.47125 ,
#        440.37625 ,  58.91129 ,  83.13476 , 204.21664 , 380.94943 ,
#        471.96478 , 204.20297 , 290.29932 , 255.5766  , 481.88583 ,
#        345.8119  , 334.77734 , 368.3034  , 321.51712 ,  84.3777  ,
#        485.9055  ,  68.8881  , 172.40204 , 222.69676 , 106.718666,
#        157.12433 , 454.61722 , 477.31033 , 164.73958 , 341.92358 ,
#        394.24142 , 405.80582 , 420.53192 , 302.46152 ,  85.46043 ,
#        350.14322 , 204.71465 , 357.26495 , 312.32996 , 350.961   ,
#        115.90732 ,  72.724266, 326.06384 , 335.8011  , 466.00555 ,
#         85.589066, 442.16315 , 281.98288 , 226.61902 ,  93.46053 ,
# ...

# %%
mmodel7.predict([[181.610932,40,16.899243,105,27.796433,9,0,3,4,0,1,0,3949.165238]])
# Out:
# array([502.54218], dtype=float32)

# %% [markdown]
# **svr**

# %%
from sklearn.svm import SVR

# %%
from sklearn.model_selection import GridSearchCV

# %%
model8=SVR()

# %%
xtrain=np.asarray(xtrain)
ytrain=np.asarray(ytrain)

# %%
parameters={'kernel':['linear','poly','rbf','sigmoid'],
            'C':[1,5,10,20]
           }

# %%
GV=GridSearchCV(model,parameters,cv=11)

# %%
GV.fit(xtrain,ytrain)
# Out:
# GridSearchCV(cv=11, estimator=SVR(),
#              param_grid={'C': [1, 5, 10, 20],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
GV.best_params_
# Out:
# {'C': 20, 'kernel': 'linear'}

# %%
model8=SVR(kernel='linear',C=20)

# %%
model8.fit(xtrain,ytrain)
# Out:
# SVR(C=20, kernel='linear')

# %%
print(model8.score(xtrain,ytrain))
print(model8.score(xtest,ytest))
# Out:
# 0.9724319881971604
# 0.9721716402282585

# %%
ypred=model8.predict(xtest)
ypred
# Out:
# array([429.38226777, 311.29462485, 242.94991334, 184.94616954,
#        368.31409299, 118.25759607, 271.1140969 , 370.5904818 ,
#        111.46015878, 152.25931356, 440.79008981, 240.72413555,
#        368.33365029, 273.0944163 , 122.68759758, 195.06788293,
#        293.62415647,  38.97349772, 275.05556271, 433.85911353,
#        164.88222541, 388.88286034,  88.59530109, 214.12349747,
#        382.2912527 , 467.76893356,  66.76079965, 117.35000645,
#        218.1430128 , 344.96535314, 488.34298197, 187.50797553,
#        290.90710322, 261.45836048, 515.72811769, 331.73981174,
#        329.11782868, 365.78478749, 322.93327799,  92.63714257,
#        453.30715274,  50.259572  , 181.55329219, 226.91401042,
#         89.53216511, 133.90722208, 437.8517095 , 491.80708766,
#        159.5684306 , 348.82835017, 388.43299647, 418.21777681,
#        429.24197671, 302.60715041,  92.68340317, 356.83537191,
#        211.65275005, 366.05742527, 325.68112729, 340.27694038,
# ...

# %%
model8.predict([[181.610932,40,16.899243,105,27.796433,9,0,3,4,0,1,0,3949.165238]])
# Out:
# array([31278.43218581])

# %%
a={'test_accuracy':[0.9722759110631494,0.994633187399748,0.7527397455849496,0.9988299898456177,0.9683581823045374,0.9981688194473542,0.9984675719260427,0.9724319881971604],
    'train_accuracy':[0.9728604807579079,1.0,0.8462403362208659,0.9998287878556177,0.9740440348599829,0.9990718620599288,0.9999837513015506,0.9721716402282585]}
df=pd.DataFrame(data=a,index=['Linear','Decision tree','k-neighbour','random forest','Adaboost','Gradientboost','XGboost','SVR'])

# %%
df.plot(kind='bar',figsize=(15,7))
# Out:
# <Axes: >

# %%
model6.predict([[181.610932,40,16.899243,105,27.796433,9,0,3,4,0,1,0,3949.165238]])
# Out:
# array([588.76980552])
